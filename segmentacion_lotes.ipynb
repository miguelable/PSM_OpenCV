# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt

def match_contours(red_contours_info, green_contours_info):
    matches = []
    used_red_contours = set()
    used_green_contours = set()

    for red_contour in red_contours_info:
        # Verificar si este contorno rojo ya está emparejado
        if id(red_contour) in used_red_contours:
            continue

        best_match = None
        best_angle_match = float('inf')  # Para encontrar el mejor ángulo
        best_score = float('inf')       # Para desempatar usando área y perímetro

        for green_contour in green_contours_info:
            # Verificar si este contorno verde ya está emparejado
            if id(green_contour) in used_green_contours:
                continue

            # Calcular distancia entre centros
            center_distance = np.linalg.norm(
                np.array(red_contour['center']) - np.array(green_contour['center'])
            )

            # Descartar si la distancia excede 3.5 veces la anchura del contorno rojo
            if center_distance > 3.2 * red_contour['width']:
                continue

            # Calcular diferencia de ángulo
            angle_diff = abs(red_contour['angle'] - green_contour['angle'])

            # Descartar si la diferencia de ángulo es mayor a 10 grados
            # if angle_diff > 20:
            #     continue

            # Calcular diferencias adicionales para desempatar
            area_diff = abs(red_contour['area'] - green_contour['area'])
            perimeter_diff = abs(red_contour['perimeter'] - green_contour['perimeter'])

            # Crear puntaje de desempate
            score = area_diff + perimeter_diff

            # Actualizar el mejor match
            if angle_diff < best_angle_match or (angle_diff == best_angle_match and score < best_score):
                best_angle_match = angle_diff
                best_score = score
                best_match = green_contour

        if best_match:
            matches.append((red_contour, best_match))
            used_red_contours.add(id(red_contour))
            used_green_contours.add(id(best_match))

    return matches

def cut_bounding_box(matched_contours, image):
    extracted_images = []

    for red_contour, green_contour in matched_contours:
        # Obtener los puntos de los contornos
        red_points = np.array(red_contour['corners'])
        green_points = np.array(green_contour['corners'])

        # Combinar los puntos de ambos contornos
        all_points = np.vstack((red_points, green_points))

        # Calcular la bounding box que contenga todos los puntos
        x_min, y_min = np.min(all_points, axis=0)
        x_max, y_max = np.max(all_points, axis=0)

        # Convertir los centros a tuplas de enteros
        red_center = tuple(map(int, red_contour['center']))
        green_center = tuple(map(int, green_contour['center']))

        # # Dibujar la línea que une los centros en la imagen original
        # cv2.line(image, red_center, green_center, (255, 0, 0), 2)

        # Calcular el ángulo entre los centros
        x0, y0 = red_contour['center']
        x1, y1 = green_contour['center']
        angle = np.arctan2(y1 - y0, x1 - x0) * 180 / np.pi

        # Rotar la imagen original para que la línea entre los centros sea horizontal
        M = cv2.getRotationMatrix2D(red_center, angle, 1)
        rotated_image = cv2.warpAffine(image, M, (image.shape[1], image.shape[0]))
        
        # Transformar las coordenadas de los contornos según la rotación
        ones = np.ones((red_points.shape[0], 1))
        red_points_homogeneous = np.hstack([red_points, ones])
        transformed_red_points = (M @ red_points_homogeneous.T).T

        green_points_homogeneous = np.hstack([green_points, ones])
        transformed_green_points = (M @ green_points_homogeneous.T).T

        # Combinar los puntos transformados
        transformed_all_points = np.vstack((transformed_red_points, transformed_green_points))

        # Calcular la nueva bounding box en la imagen rotada
        x_min, y_min = np.min(transformed_all_points, axis=0).astype(int)
        x_max, y_max = np.max(transformed_all_points, axis=0).astype(int)

        # Validar las coordenadas para asegurarse de que estén dentro de los límites
        h, w = rotated_image.shape[:2]
        x_min, x_max = max(0, x_min), min(w, x_max)
        y_min, y_max = max(0, y_min), min(h, y_max)

        # Verificar que las dimensiones del recorte sean válidas
        if x_min < x_max and y_min < y_max:
            cropped_image = rotated_image[y_min:y_max, x_min:x_max]

            if cropped_image.size > 0:  # Comprobar que el recorte no sea vacío
                extracted_images.append(cropped_image)
            else:
                print(f"Warning: Empty crop for contours {red_contour['center']} and {green_contour['center']}")
        else:
            print(f"Warning: Invalid crop coordinates for contours {red_contour['center']} and {green_contour['center']}")

    return extracted_images

def process_image(image_path):
    # Cargar la imagen
    image = cv2.imread(image_path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    # Desenfoque
    image_blurred = cv2.GaussianBlur(image, (7, 7), 0)

    # Convertir a escala de grises y HSV
    gray_image = cv2.cvtColor(image_blurred, cv2.COLOR_RGB2GRAY)
    hsv_image = cv2.cvtColor(image_blurred, cv2.COLOR_RGB2HSV)

    # Aplicar máscaras roja y verde
    def apply_red_mask(hsv_image):
        lower_red = np.array([125, 20, 0])
        upper_red = np.array([179, 255, 255])
        return cv2.inRange(hsv_image, lower_red, upper_red)

    def apply_green_mask(hsv_image):
        lower_green = np.array([50, 40, 0])
        upper_green = np.array([110, 255, 160])
        return cv2.inRange(hsv_image, lower_green, upper_green)

    mask_red = apply_red_mask(hsv_image)
    mask_green = apply_green_mask(hsv_image)

    # Erosionar y cerrar las máscaras
    def close_erode_mask(mask):
        kernel = np.ones((7, 7), np.uint16)
        mask_closed = cv2.morphologyEx(mask, cv2.MORPH_CLOSE, kernel)
        kernel = np.ones((5, 5), np.uint16)
        return cv2.dilate(mask_closed, kernel, iterations=1)

    mask_red = close_erode_mask(mask_red)
    mask_green = close_erode_mask(mask_green)

    # Segmentar las imágenes usando las máscaras
    def apply_mask_to_image(image, mask):
        return cv2.bitwise_and(image, image, mask=mask)

    segmented_red = apply_mask_to_image(gray_image, mask_red)
    segmented_green = apply_mask_to_image(gray_image, mask_green)

    # Aplicar el filtro Sobel
    def sobel_filter_image(image, kernel_size):
        img_sobel_x = cv2.Sobel(image, cv2.CV_64F, 1, 0, ksize=kernel_size)
        img_sobel_y = cv2.Sobel(image, cv2.CV_64F, 0, 1, ksize=kernel_size)
        img_sobel = np.sqrt(img_sobel_x**2 + img_sobel_y**2)
        img_sobel = cv2.normalize(img_sobel, None, 0, 255, cv2.NORM_MINMAX, cv2.CV_8U)
        _, filtered_image = cv2.threshold(img_sobel, 30, 255, cv2.THRESH_BINARY)
        return filtered_image

    filtered_green = sobel_filter_image(segmented_green, 11)
    filtered_red = sobel_filter_image(segmented_red, 11)

    # Encontrar contornos
    def find_contours(filtered_image):
        contours, _ = cv2.findContours(filtered_image, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
        filtered_contours = [
            contour for contour in contours
            if cv2.contourArea(contour) > 4000 and 0.5 < cv2.boundingRect(contour)[2] / cv2.boundingRect(contour)[3] < 1.3
        ]
        return filtered_contours

    filtered_green_contours = find_contours(filtered_green)
    filtered_red_contours = find_contours(filtered_red)

    # Extraer información de los contornos
    def extract_contour_info(contours):
        contour_info = []
        for contour in contours:
            area = round(cv2.contourArea(contour), 3)
            x, y, w, h = cv2.boundingRect(contour)
            perimeter = round(cv2.arcLength(contour, True), 3)
            rect = cv2.minAreaRect(contour)
            box = cv2.boxPoints(rect)
            box = np.int16(box)
            corners = [(corner[0], corner[1]) for corner in box]
            contour_info.append({
                'corners': corners,
                'center': (round(x + w / 2, 3), round(y + h / 2, 3)),
                'width': round(w, 3),
                'height': round(h, 3),
                'area': area,
                'aspect_ratio': round(w / h, 3) if h != 0 else None,
                'perimeter': perimeter,
                'angle': round(rect[-1], 3)
            })
        return contour_info

    green_contour_info = extract_contour_info(filtered_green_contours)
    red_contour_info = extract_contour_info(filtered_red_contours)

    # Emparejar contornos
    matched_contours = match_contours(red_contour_info, green_contour_info)

    # Cortar imágenes de los contornos emparejados
    extracted_images = cut_bounding_box(matched_contours, image)

    return extracted_images

# Ruta de la carpeta con las imágenes
input_folder = r"Real Images"
output_folder = r"Processed Images"
os.makedirs(output_folder, exist_ok=True)

# Procesar todas las imágenes
for file_name in os.listdir(input_folder):
    file_path = os.path.join(input_folder, file_name)
    if file_name.lower().endswith(('.png', '.jpg', '.jpeg')):
        print(f"Processing {file_name}...")
        extracted_images = process_image(file_path)
        for i, img in enumerate(extracted_images):
            output_path = os.path.join(output_folder, f"{os.path.splitext(file_name)[0]}_extracted_{i+1}.jpg")
            cv2.imwrite(output_path, cv2.cvtColor(img, cv2.COLOR_RGB2BGR))
# Out:
# Processing 0000_1_04_10.png...
# Angle between centers: -98.92°
# Processing 0000_1_04_4.png...
# Processing 0000_1_04_9.png...
# Angle between centers: -24.22°
# Processing 1103_1_G1_1.jpg...
# Angle between centers: 148.19°
# Processing 1103_1_G1_2.jpg...
# Angle between centers: 70.01°
# Processing 1103_1_G1_3.jpg...
# Angle between centers: 26.36°
# Processing 1103_1_G1_4.jpg...
# Angle between centers: 28.27°
# Processing 1103_1_G2_00.jpg...
# Angle between centers: -3.45°
# Processing 1103_1_G2_01.jpg...
# Angle between centers: 93.45°
# Processing 1103_1_G2_02.jpg...
# Angle between centers: -174.94°
# Processing 1103_1_G2_03.jpg...
# Angle between centers: -81.26°
# Processing 1103_1_G2_04.jpg...
# Processing 1111_1_04_10.png...
# Processing 1111_1_04_11.png...
# Angle between centers: 3.95°
# Processing 1111_1_04_12.png...
# Angle between centers: 26.96°
# Processing 1111_1_04_13.png...
# Angle between centers: -103.44°
# Processing 1234_1_04_1.png...
# Angle between centers: 173.89°
# Processing 1234_1_04_2.png...
# Angle between centers: 83.81°
# Processing 1234_1_04_3.png...
# Angle between centers: -4.83°
# Processing 1910_1_G1_1.jpg...
# Angle between centers: -178.71°
# Processing 1910_1_G1_2.jpg...
# Angle between centers: 95.12°
# Processing 1910_1_G1_3.jpg...
# Angle between centers: -95.98°
# Processing 1910_1_G1_4.jpg...
# Processing 1910_1_G2_00.jpg...
# Processing 1910_1_G2_01.jpg...
# Processing 1910_1_G2_02.jpg...
# Processing 1910_1_G2_03.jpg...
# Processing 1910_1_G2_04.jpg...
# Processing 1910_1_G2_05.jpg...
# Angle between centers: 169.47°
# Processing 1910_1_G2_06.jpg...
# Angle between centers: 79.48°
# Processing 1910_1_G2_07.jpg...
# Angle between centers: -20.65°
# Processing 1910_1_G2_08.jpg...
# Angle between centers: -98.60°
# Processing 1910_1_G2_09.jpg...
# Angle between centers: 166.32°
# Processing 1910_1_G2_10.jpg...
# Angle between centers: 171.67°
# Processing 1910_1_G2_11.jpg...
# Angle between centers: 171.65°
# Processing 1910_1_G2_12.jpg...
# Angle between centers: 171.87°
# Processing 1910_1_G2_13.jpg...
# Angle between centers: 142.50°
# Processing 1910_1_G2_14.jpg...
# Angle between centers: 79.22°
# Processing 2222_1_04_13.png...
# Angle between centers: -119.74°
# Processing 2222_1_04_14.png...
# Angle between centers: 116.57°
# Processing 2222_1_04_15.png...
# Angle between centers: 114.63°
# Processing 2222_1_04_16.png...
# Angle between centers: 102.84°
# Processing 2321_1_G2_00.jpg...
# Processing 2321_1_G2_01.jpg...
# Angle between centers: 172.96°
# Processing 2321_1_G2_02.jpg...
# Angle between centers: 94.21°
# Processing 2321_1_G2_03.jpg...
# Angle between centers: 94.32°
# Processing 2321_1_G2_04.jpg...
# Angle between centers: -12.75°
# Processing 2321_1_G2_05.jpg...
# Angle between centers: -155.34°
# Processing 2370_1_G2_00.jpg...
# Angle between centers: -9.99°
# Processing 2370_1_G2_01.jpg...
# Angle between centers: 88.34°
# Processing 2370_1_G2_02.jpg...
# Angle between centers: 169.18°
# Processing 2370_1_G2_03.jpg...
# Angle between centers: -92.27°
# Processing 2370_1_G2_04.jpg...
# Processing 2370_1_G2_05.jpg...
# Processing 2884_1_G2_00.jpg...
# Processing 2884_1_G2_01.jpg...
# Angle between centers: -101.62°
# Processing 2884_1_G2_02.jpg...
# Processing 2884_1_G2_03.jpg...
# Angle between centers: 75.96°
# Processing 2884_1_G2_04.jpg...
# Processing 2884_1_G2_05.jpg...
# Processing 2884_1_G2_06.jpg...
# Processing 2884_1_G2_07.jpg...
# Processing 2884_1_G2_08.jpg...
# Processing 3333_1_04_10.png...
# Angle between centers: 20.16°
# Processing 3333_1_04_11.png...
# Angle between centers: 24.94°
# Processing 3333_1_04_12.png...
# Angle between centers: 51.02°
# Processing 3333_1_04_13.png...
# Angle between centers: -96.10°
# Processing 3490_1_G1_1.jpg...
# Angle between centers: 173.34°
# Processing 3490_1_G1_2.jpg...
# Angle between centers: -132.71°
# Processing 3490_1_G1_3.jpg...
# Angle between centers: -96.50°
# Processing 3490_1_G1_4.jpg...
# Angle between centers: -44.62°
# Processing 3490_1_G1_5.jpg...
# Angle between centers: 43.98°
# Processing 3490_1_G1_6.jpg...
# Processing 3490_1_G1_7.jpg...
# Angle between centers: -146.64°
# Processing 3490_1_G1_8.jpg...
# Processing 3490_1_G1_9.jpg...
# Angle between centers: -53.45°
# Processing 4444_1_04_11.png...
# Angle between centers: -149.14°
# Processing 4444_1_04_12.png...
# Angle between centers: -33.64°
# Processing 4444_1_04_13.png...
# Processing 4444_1_04_14.png...
# Angle between centers: -48.79°
# Processing 4966_0_G2_00.jpg...
# Angle between centers: 158.20°
# Processing 4966_0_G2_01.jpg...
# Processing 4966_0_G2_02.jpg...
# Angle between centers: -62.75°
# Processing 4966_0_G2_03.jpg...
# Angle between centers: 135.00°
# Processing 4966_1_G1_1.jpg...
# Angle between centers: 23.20°
# Processing 4966_1_G1_2.jpg...
# Angle between centers: 145.32°
# Processing 4966_1_G1_3.jpg...
# Angle between centers: 67.75°
# Processing 4966_1_G1_4.jpg...
# Angle between centers: 45.12°
# Processing 4966_1_G1_5.jpg...
# Angle between centers: -176.51°
# Processing 4966_1_G1_6.jpg...
# Processing 5555_1_04_13.png...
# Angle between centers: -156.44°
# Processing 5555_1_04_14.png...
# Angle between centers: 96.12°
# Processing 5555_1_04_15.png...
# Angle between centers: 61.47°
# Processing 5555_1_04_16.png...
# Processing 6666_1_04_14.png...
# Angle between centers: -45.92°
# Processing 6666_1_04_15.png...
# Angle between centers: -44.11°
# Processing 6666_1_04_16.png...
# Angle between centers: -112.30°
# Processing 6666_1_04_17.png...
# Processing 6804_1_G1_1.jpg...
# Angle between centers: -177.46°
# Processing 6804_1_G1_2.jpg...
# Angle between centers: -141.71°
# Processing 6804_1_G1_3.jpg...
# Angle between centers: -127.33°
# Processing 6804_1_G1_4.jpg...
# Angle between centers: -16.09°
# Processing 6804_1_G1_5.jpg...
# Angle between centers: -0.71°
# Processing 6936_1_G2_00.jpg...
# Angle between centers: 172.26°
# Processing 6936_1_G2_01.jpg...
# Angle between centers: 72.94°
# Processing 6936_1_G2_02.jpg...
# Angle between centers: -13.23°
# Processing 6936_1_G2_03.jpg...
# Angle between centers: -98.76°
# Processing 6936_1_G2_04.jpg...
# Angle between centers: -89.14°
# Processing 6936_1_G2_05.jpg...
# Angle between centers: -86.29°
# Processing 6936_1_G2_06.jpg...
# Angle between centers: -86.23°
# Processing 6936_1_G2_07.jpg...
# Angle between centers: -85.53°
# Processing 6936_1_G2_08.jpg...
# Angle between centers: -86.24°
# Processing 6936_1_G2_09.jpg...
# Angle between centers: 170.74°
# Processing 6936_1_G2_10.jpg...
# Angle between centers: -100.78°
# Processing 6936_1_G2_11.jpg...
# Angle between centers: -106.63°
# Processing 6936_1_G2_12.jpg...
# Angle between centers: -107.41°
# Processing 6936_1_G2_13.jpg...
# Angle between centers: 13.10°
# Processing 6936_1_G2_14.jpg...
# Angle between centers: -4.24°
# Processing 6936_1_G2_15.jpg...
# Angle between centers: -72.90°
# Processing 7381_1_G1_1.jpg...
# Angle between centers: -176.63°
# Processing 7381_1_G1_2.jpg...
# Angle between centers: -119.59°
# Processing 7381_1_G1_3.jpg...
# Processing 7381_1_G1_4.jpg...
# Angle between centers: 72.58°
# Processing 7381_1_G2_00.jpg...
# Angle between centers: -4.33°
# Processing 7381_1_G2_01.jpg...
# Angle between centers: -95.18°
# Processing 7381_1_G2_02.jpg...
# Angle between centers: 173.15°
# Processing 7381_1_G2_03.jpg...
# Angle between centers: 80.89°
# Processing 7381_1_G2_04.jpg...
# Angle between centers: 165.39°
# Processing 7381_1_G2_05.jpg...
# Processing 7381_1_G2_06.jpg...
# Angle between centers: -102.30°
# Processing 7777_1_04_11.png...
# Angle between centers: -83.77°
# Processing 7777_1_04_12.png...
# Angle between centers: -60.57°
# Processing 7777_1_04_13.png...
# Processing 7777_1_04_14.png...
# Processing 7777_1_04_15.png...
# Angle between centers: 131.51°
# Processing 8440_1_G1_1.jpg...
# Angle between centers: -0.32°
# Processing 8440_1_G1_2.jpg...
# Angle between centers: 69.27°
# Processing 8440_1_G1_3.jpg...
# Processing 8440_1_G1_4.jpg...
# Angle between centers: 32.67°
# Processing 8440_1_G1_5.jpg...
# Angle between centers: 162.30°
# Processing 8888_1_04_10.png...
# Angle between centers: -98.56°
# Processing 8888_1_04_11.png...
# Angle between centers: 160.41°
# Processing 8888_1_04_12.png...
# Angle between centers: 163.74°
# Processing 8888_1_04_13.png...
# Angle between centers: -69.08°
# Processing 9092_1_G2_00.jpg...
# Angle between centers: -8.62°
# Processing 9092_1_G2_01.jpg...
# Angle between centers: -93.73°
# Processing 9092_1_G2_02.jpg...
# Angle between centers: 160.03°
# Processing 9092_1_G2_03.jpg...
# Angle between centers: 76.68°
# Processing 9092_1_G2_04.jpg...
# Angle between centers: 51.87°
# Processing 9092_1_G2_05.jpg...
# Processing 9277_1_G1_1.jpg...
# Angle between centers: 5.34°
# Processing 9277_1_G1_10.jpg...
# Processing 9277_1_G1_2.jpg...
# Angle between centers: 46.08°
# Processing 9277_1_G1_3.jpg...
# Angle between centers: 107.42°
# Processing 9277_1_G1_4.jpg...
# Angle between centers: -173.57°
# Processing 9277_1_G1_5.jpg...
# Processing 9277_1_G1_6.jpg...
# Angle between centers: -104.04°
# Processing 9277_1_G1_7.jpg...
# Processing 9277_1_G1_8.jpg...
# Processing 9277_1_G1_9.jpg...
# Processing 9999_1_04_14.png...
# Angle between centers: -162.76°
# Processing 9999_1_04_15.png...
# Angle between centers: 4.02°
# Processing 9999_1_04_16.png...
# Angle between centers: 0.81°
# Processing 9999_1_04_17.png...
# Angle between centers: -11.29°
# Processing mix_1_G1_1.jpg...
# Angle between centers: -118.97°
# Angle between centers: -21.98°
# Angle between centers: 48.37°
# Processing mix_1_G1_2.jpg...
# Angle between centers: 15.77°
# Angle between centers: 76.96°
# Processing mix_1_G1_3.jpg...
# Angle between centers: 17.36°
# Processing mix_1_G1_4.jpg...
# Angle between centers: -97.60°
# Angle between centers: 16.00°
# Angle between centers: 47.18°
# Processing mix_1_G1_52.jpg...
# Angle between centers: 16.40°
# Angle between centers: -95.61°
# Angle between centers: -56.94°
# Processing mix_1_G1_53.jpg...
# Angle between centers: -95.62°
# Angle between centers: -56.95°
# Angle between centers: 92.40°
# Processing mix_1_G1_54.jpg...
# Angle between centers: 84.34°
# Angle between centers: -151.86°
# Angle between centers: 72.60°
# Processing mix_1_G1_55.jpg...
# Angle between centers: -168.36°
# Angle between centers: -68.83°
# Angle between centers: 136.24°
# Processing mix_1_G1_56.jpg...
# Angle between centers: -118.22°
# Angle between centers: -154.96°
# Angle between centers: 11.56°
# Processing mix_1_G1_57.jpg...
# Angle between centers: 16.84°
# Processing mix_1_G1_58.jpg...
# Angle between centers: -71.51°
# Angle between centers: -154.31°
# Angle between centers: 107.31°
# Processing mix_1_G1_59.jpg...
# Angle between centers: 147.55°
# Angle between centers: 153.43°
# Processing mix_1_G1_60.jpg...
# Angle between centers: -84.65°
# Angle between centers: -152.38°
# Angle between centers: 17.29°
# Processing mix_1_G1_61.jpg...
# Angle between centers: -48.30°
# Angle between centers: -46.39°
# Processing mix_1_G1_62.jpg...
# Angle between centers: 20.85°
# Angle between centers: -106.45°
# Angle between centers: 28.42°
# Processing mix_1_G1_63.jpg...
# Angle between centers: -133.54°
# Angle between centers: 27.00°
# Processing mix_1_G1_64.jpg...
# Angle between centers: -10.95°
# Angle between centers: -13.59°
# Angle between centers: 115.18°
# Angle between centers: 28.44°
# Angle between centers: -46.12°
# Angle between centers: 18.72°
# Processing mix_1_G1_65.jpg...
# Angle between centers: -90.89°
# Angle between centers: -27.90°
# Angle between centers: 169.77°
# Angle between centers: -63.28°
# Angle between centers: 66.65°
# Angle between centers: 55.73°
# Processing mix_1_G1_66.jpg...
# Angle between centers: 82.80°
# Angle between centers: -63.27°
# Processing mix_1_G1_67.jpg...
# Angle between centers: 9.72°
# Angle between centers: 82.47°
# Angle between centers: -58.01°
# Angle between centers: -103.50°
